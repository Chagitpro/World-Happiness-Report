# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df=pd.DataFrame(data=df)
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt= '.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.iloc[:,0]
# Out:
# 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 153         Rwanda
# 154          Benin
# 155          Syria
# 156        Burundi
# 157           Togo
# Name: Country, Length: 158, dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.hist(bins='auto', figsize=(15,15));

# %%
plt.figure(figsize=(15, 10))

# %%
happiness_score = df['Happiness Score']
gdp= df['Economy (GDP per Capita)']

plt.scatter(happiness_score, gdp)
plt.title('Scatter plot of Happiness vs Economy (GDP per Capita)')
plt.xlabel('Happiness Score')
plt.ylabel('Economy (GDP per Capita)')
plt.show()

# %%
happiness_score = df['Happiness Score']
Family= df['Family']

plt.scatter(happiness_score, Family)
plt.title('Scatter plot of Happiness vs Family')
plt.xlabel('Happiness Score')
plt.ylabel('Family')
plt.show()

# %%
happiness_score = df['Happiness Score']
Health= df['Health (Life Expectancy)']

plt.scatter(happiness_score, Health)
plt.title('Scatter plot of Happiness vs Health (Life Expectancy)')
plt.xlabel('Happiness Score')
plt.ylabel('Health (Life Expectancy')
plt.show()

# %%
happiness_score = df['Happiness Score']
Freedom= df['Freedom']

plt.scatter(happiness_score, Freedom)
plt.title('Scatter plot of Happiness vs Freedom')
plt.xlabel('Happiness Score')
plt.ylabel('Freedom')
plt.show()

# %%
happiness_score = df['Happiness Score']
Generosity= df['Generosity']

plt.scatter(happiness_score, Generosity)
plt.title('Scatter plot of Happiness vs Generosity')
plt.xlabel('Happiness Score')
plt.ylabel('Generosity')
plt.show()

# %%
happiness_score = df['Happiness Score']
Trust= df['Trust (Government Corruption)']

plt.scatter(happiness_score, Trust)
plt.title('Scatter plot of Happiness vs Trust (Government Corruption)')
plt.xlabel('Happiness Score')
plt.ylabel('Trust (Government Corruption)')
plt.show()

# %%
Happiness_countries = df[['Country', 'Happiness Score']].groupby('Country').mean().sort_values(by = 'Happiness Score', ascending = True)
Happiness_countries.head()
# Out:
#          Happiness Score
# Country
# Togo               2.839
# Burundi            2.905
# Syria              3.006
# Benin              3.340
# Rwanda             3.465

# %%
Happiness_countries = df[['Country', 'Happiness Score']].groupby('Country').mean().sort_values(by = 'Happiness Score', ascending = True)
Happiness_countries.tail()
# Out:
#              Happiness Score
# Country
# Canada                 7.427
# Norway                 7.522
# Denmark                7.527
# Iceland                7.561
# Switzerland            7.587

# %%
gdp_countries = df[['Country', 'Economy (GDP per Capita)']].groupby('Country').mean().sort_values(by = 'Economy (GDP per Capita)', ascending = True)
gdp_countries.head()
# Out:
#                   Economy (GDP per Capita)
# Country
# Congo (Kinshasa)                   0.00000
# Burundi                            0.01530
# Malawi                             0.01604
# Niger                              0.06940
# Liberia                            0.07120

# %%
gdp_countries = df[['Country', 'Economy (GDP per Capita)']].groupby('Country').mean().sort_values(by = 'Economy (GDP per Capita)', ascending = True)
gdp_countries.tail()
# Out:
#             Economy (GDP per Capita)
# Country
# Norway                       1.45900
# Singapore                    1.52186
# Kuwait                       1.55422
# Luxembourg                   1.56391
# Qatar                        1.69042

# %%
trust_countries = df[['Country', 'Trust (Government Corruption)']].groupby('Country').mean().sort_values(by = 'Trust (Government Corruption)', ascending = True)
trust_countries.head()
# Out:
#                         Trust (Government Corruption)
# Country
# Indonesia                                     0.00000
# Bosnia and Herzegovina                        0.00227
# Romania                                       0.00649
# Bulgaria                                      0.00872
# Lithuania                                     0.01031

# %%
trust_countries = df[['Country', 'Trust (Government Corruption)']].groupby('Country').mean().sort_values(by = 'Trust (Government Corruption)', ascending = True)
trust_countries.tail()
# Out:
#            Trust (Government Corruption)
# Country
# Sweden                           0.43844
# Denmark                          0.48357
# Singapore                        0.49210
# Qatar                            0.52208
# Rwanda                           0.55191

# %%
health_countries = df[['Country', 'Health (Life Expectancy)']].groupby('Country').mean().sort_values(by = 'Health (Life Expectancy)', ascending = True)
health_countries.head()
# Out:
#                           Health (Life Expectancy)
# Country
# Sierra Leone                               0.00000
# Botswana                                   0.04776
# Central African Republic                   0.06699
# Swaziland                                  0.07566
# Lesotho                                    0.07612

# %%
health_countries = df[['Country', 'Health (Life Expectancy)']].groupby('Country').mean().sort_values(by = 'Health (Life Expectancy)', ascending = True)
health_countries.tail()
# Out:
#              Health (Life Expectancy)
# Country
# Spain                         0.95562
# South Korea                   0.96538
# Japan                         0.99111
# Hong Kong                     1.01328
# Singapore                     1.02525

# %%
Generosity_countries = df[['Country', 'Generosity']].groupby('Country').mean().sort_values(by = 'Generosity', ascending = True)
Generosity_countries.head()
# Out:
#            Generosity
# Country
# Greece        0.00000
# Russia        0.00199
# Lithuania     0.02641
# Croatia       0.05444
# Georgia       0.05547

# %%
Generosity_countries = df[['Country', 'Generosity']].groupby('Country').mean().sort_values(by = 'Generosity', ascending = True)
Generosity_countries.tail()
# Out:
#                 Generosity
# Country
# Indonesia          0.51535
# Malta              0.51752
# United Kingdom     0.51912
# Thailand           0.57630
# Myanmar            0.79588

# %%
Family_countries = df[['Country', 'Family']].groupby('Country').mean().sort_values(by = 'Family', ascending = True)
Family_countries.head()
# Out:
#                            Family
# Country
# Central African Republic  0.00000
# Togo                      0.13995
# Afghanistan               0.30285
# Benin                     0.35386
# India                     0.38174

# %%
Family_countries = df[['Country', 'Family']].groupby('Country').mean().sort_values(by = 'Family', ascending = True)
Family_countries.tail()
# Out:
#               Family
# Country
# Uzbekistan   1.34043
# Switzerland  1.34951
# Denmark      1.36058
# Ireland      1.36948
# Iceland      1.40223

# %%
Freedom_countries = df[['Country', 'Freedom']].groupby('Country').mean().sort_values(by = 'Freedom', ascending = True)
Freedom_countries.head()
# Out:
#                         Freedom
# Country
# Iraq                    0.00000
# Greece                  0.07699
# Bosnia and Herzegovina  0.09245
# Sudan                   0.10081
# Angola                  0.10384

# %%
Freedom_countries = df[['Country', 'Freedom']].groupby('Country').mean().sort_values(by = 'Freedom', ascending = True)
Freedom_countries.tail()
# Out:
#              Freedom
# Country
# Uzbekistan   0.65821
# Sweden       0.65980
# Cambodia     0.66246
# Switzerland  0.66557
# Norway       0.66973

# %%
rank_countries = df[['Country', 'Happiness Rank']].groupby('Country').mean().sort_values(by = 'Happiness Rank', ascending = True)
rank_countries.head()
# Out:
#              Happiness Rank
# Country
# Switzerland               1
# Iceland                   2
# Denmark                   3
# Norway                    4
# Canada                    5

# %%
rank_countries = df[['Country', 'Happiness Rank']].groupby('Country').mean().sort_values(by = 'Happiness Rank', ascending = True)
rank_countries.tail()
# Out:
#          Happiness Rank
# Country
# Rwanda              154
# Benin               155
# Syria               156
# Burundi             157
# Togo                158

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom',]]
y=df['Happiness Score']

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
print(lm.coef_)
# Out:
# [0.91475704 1.41867853 0.90283593 1.9341315 ]

# %%
y_pred= lm.predict(x_test)

actual_vs_pred = pd.DataFrame({'Actual': y_test, 'Predicted':y_pred})
actual_vs_pred
# Out:
#      Actual  Predicted
# 7     7.364   6.949774
# 44    5.995   6.001739
# 113   4.633   4.448699
# 120   4.514   4.613922
# 63    5.716   5.912345
# 122   4.507   4.252135
# 121   4.512   4.073864
# 139   3.956   3.918721
# 109   4.686   4.710638
# 92    5.007   5.377577
# 24    6.786   6.245159
# 141   3.904   4.627382
# 26    6.670   6.041054
# 60    5.770   6.030740
# 80    5.194   3.635186
# 97    4.885   6.004839
# 129   4.297   4.473244
# 98    4.876   5.039945
# 142   3.896   5.067301
# 56    5.828   5.710777
# 45    5.987   6.604597
# 33    6.455   6.226824
# 59    5.791   6.379862
# 8     7.286   6.876853
# 40    6.168   6.227854
# 37    6.298   6.070849
# 101   4.857   5.123733
# 19    6.901   6.678484
# 144   3.819   4.948503
# 108   4.694   4.112174
# 51    5.889   4.981392
# 54    5.848   6.660979

# %%
coefficient = lm.coef_

coefficient_df=pd.DataFrame(list(zip(x.columns,lm.coef_)), columns=['features','coefficients'])
coefficient_df
# Out:
#                    features  coefficients
# 0  Economy (GDP per Capita)      0.914757
# 1                    Family      1.418679
# 2  Health (Life Expectancy)      0.902836
# 3                   Freedom      1.934132

# %% [markdown]
# # Conclusion

# %% [raw]
# Economy (GDP per Capita), Freedom to make life choices and Health (Life Expectancy) are great determinants of Happiness score and can be used to predict the future scores. However, this is not conclusive because unforeseen occurences like pandemic, natural disasters and economic meltdown happen, even to the most stable countries so these scores can actually change.
